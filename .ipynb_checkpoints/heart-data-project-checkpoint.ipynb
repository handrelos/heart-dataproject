# %%
#pip install pip install jupyterlab== 4.0.8
#pip install jupyterlab-git== 2.31.1.windows.1
#for git to work*

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
from scipy.stats import spearmanr
from scipy.stats import pearsonr

# %%
df = pd.read_csv("C:/Users/Hansel/Desktop/jupyter/data-project/heart-dataproject/heart.csv")

# %%
# #Initial insights on data

df.head(10)

# print(df.info(),"\n") #918 entires

# print(df.shape, "\n") #shape of data

# print(df.nunique(), "\n") #unique data types

# print(df.describe(), "\n") #distribution of data
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
#Checking for missing values

#df.isnull().sum()

# %%
# Find rows where column 'B' is 0
rows_zero = df.loc[df['Cholesterol'] == 0]

#print(rows_zero)

#172 rows of cholesterol "0" is an error.
#how might we tackle this?
    #impute mean, mode, regression?
    #remove those 172 data points?   (we'll do this for now)
#rows_zero.shape

# %%
new_df = df.loc[~df['Cholesterol'].eq(0)]   #df with dropped values of 0 cholesterol

# %%
fig, ((a1, a2), (a3, a4)) = plt.subplots(2, 2, figsize=(10, 5))

a1.scatter(new_df['Age'], new_df['Cholesterol'], s = 10)
a1.set_title('Age vs Cholesterol')
a1.set_xlabel('Age')
a1.set_ylabel('Cholesterol')

a2.scatter(new_df['Age'], new_df['RestingBP'],color = "green", s = 10)
a2.set_title('Age vs RestingBP')
a2.set_xlabel('Age')
a2.set_ylabel('RestingBP')

a3.scatter(new_df['Age'], new_df['MaxHR'],color = "red", s = 10)
a3.set_title('Age vs MaxHR')
a3.set_xlabel('Age')
a3.set_ylabel('MaxHR')

a4.set_title("Age Distribution")
a4.set_xlabel('Age')
a4.set_ylabel('Count')
sns.histplot(new_df['Age'], kde = True)

mean = np.mean(new_df['Age'])
a4.axvline(mean, color='r', linestyle='dashed', linewidth=1)
a4.plot(kind = "kde")

plt.tight_layout()
plt.box(True)
plt.grid()
plt.show()

# %%
#AGE VS X CORRELATION COMPARISONS: PEARSONS CORRELATION
corr, _ = pearsonr(new_df['Age'], new_df['Cholesterol'])
print('Age vs Cholesterol: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['Age'], new_df['RestingBP'])
print('Age vs RestingBP: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['Age'], new_df['MaxHR'])
print('Age vs MaxHR: Pearsons correlation: %.3f' % corr)
# Out:
# Age vs Cholesterol: Pearsons correlation: 0.059
# Age vs RestingBP: Pearsons correlation: 0.260
# Age vs MaxHR: Pearsons correlation: -0.382

# %%
fig, ((a5, a6), (a7, a8)) = plt.subplots(2, 2, figsize=(10, 5))

a5.scatter(new_df['Cholesterol'], new_df['Age'], s = 10)
a5.set_title('Cholesterol vs Age')
a5.set_xlabel('Cholesterol')
a5.set_ylabel('Age')

a6.scatter(new_df['Cholesterol'], new_df['RestingBP'],color = "green", s = 10)
a6.set_title('Cholesterol vs RestingBP')
a6.set_xlabel('Cholesterol')
a6.set_ylabel('RestingBP')

a7.scatter(new_df['Cholesterol'], new_df['MaxHR'],color = "red", s = 10)
a7.set_title('Cholesterol vs MaxHR')
a7.set_xlabel('Cholesterol')
a7.set_ylabel('MaxHR')

a8.set_title('Cholesterol Distribution')
a8.set_xlabel('Cholesterol')
a8.set_ylabel('Count')
sns.histplot(new_df['Cholesterol'], kde = True)

mean = np.mean(new_df['Cholesterol'])
a8.axvline(mean, color='r', linestyle='dashed', linewidth=1)
a8.plot(kind = "kde")

plt.tight_layout()
plt.box(True)
plt.grid()
plt.show()

# %%
corr, _ = pearsonr(new_df['Cholesterol'], new_df['Age'])
print('Cholesterol vs Age: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['Cholesterol'], new_df['RestingBP'])
print('Cholesterol vs RestingBP: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['Cholesterol'], new_df['MaxHR'])
print('Cholesterol vs MaxHR: Pearsons correlation: %.3f' % corr)
# Out:
# Cholesterol vs Age: Pearsons correlation: 0.059
# Cholesterol vs RestingBP: Pearsons correlation: 0.096
# Cholesterol vs MaxHR: Pearsons correlation: -0.020

# %%
fig, ((a9, a10), (a11, a12)) = plt.subplots(2, 2, figsize=(10, 5))

a9.scatter(new_df['MaxHR'], new_df['Age'], s = 10)
a9.set_title('MaxHR vs Age')
a9.set_xlabel('MaxHR')
a9.set_ylabel('Age')

a10.scatter(new_df['MaxHR'], new_df['Cholesterol'],color = "green", s = 10)
a10.set_title('MaxHR vs Cholesterol')
a10.set_xlabel('MaxHR')
a10.set_ylabel('Cholesterol')

a11.scatter(new_df['MaxHR'], new_df['RestingBP'],color = "red", s = 10)
a11.set_title('MaxHR vs RestingBP')
a11.set_xlabel('MaxHR')
a11.set_ylabel('RestingBP')

#a12.hist(df['MaxHR'], density = True)
a12.set_title('MaxHR Distribution')
a12.set_xlabel('MaxHR')
a12.set_ylabel('Count')
sns.histplot(new_df['MaxHR'], kde = True)

mean = np.mean(new_df['MaxHR'])
a12.axvline(mean, color='r', linestyle='dashed', linewidth=1)
a12.plot(kind = "kde")

plt.tight_layout()
plt.box(True)
plt.grid()
plt.show()

# %%
corr, _ = pearsonr(new_df['MaxHR'], new_df['Age'])
print('MaxHR vs Age: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['MaxHR'], new_df['RestingBP'])
print('MaxHR vs RestingBP: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['MaxHR'], new_df['Cholesterol'])
print('MaxHR vs Cholesterol: Pearsons correlation: %.3f' % corr)
# Out:
# MaxHR vs Age: Pearsons correlation: -0.382
# MaxHR vs RestingBP: Pearsons correlation: -0.126
# MaxHR vs MaxHR: Pearsons correlation: -0.020

# %%
fig, ((a13, a14), (a15, a16)) = plt.subplots(2, 2, figsize=(10, 5))

a13.scatter(new_df['RestingBP'], new_df['Age'], s = 10)
a13.set_title('RestingBP vs Age')
a13.set_xlabel('RestingBP')
a13.set_ylabel('Age')

a14.scatter(new_df['RestingBP'], new_df['Cholesterol'],color = "green", s = 10)
a14.set_title('RestingBP vs Cholesterol')
a14.set_xlabel('RestingBP')
a14.set_ylabel('Cholesterol')

a15.scatter(new_df['RestingBP'], new_df['MaxHR'],color = "red", s = 10)
a15.set_title('RestingBP vs MaxHR')
a15.set_xlabel('RestingBP')
a15.set_ylabel('MaxHR')

#a12.hist(df['MaxHR'], density = True)
a16.set_title('RestingBP Distribution')
a16.set_xlabel('RestingBP')
a16.set_ylabel('Count')
sns.histplot(new_df['RestingBP'], kde = True)

mean = np.mean(new_df['RestingBP'])
a16.axvline(mean, color='r', linestyle='dashed', linewidth=1)
a16.plot(kind = "kde")

plt.tight_layout()
plt.box(True)
plt.grid()
plt.show()

# %%
corr, _ = pearsonr(new_df['RestingBP'], new_df['Age'])
print('RestingBP vs Age: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['RestingBP'], new_df['Cholesterol'])
print('RestingBP vs Cholesterol: Pearsons correlation: %.3f' % corr)

corr, _ = pearsonr(new_df['RestingBP'], new_df['MaxHR'])
print('RestingBP vs MaxHR: Pearsons correlation: %.3f' % corr)
# Out:
# RestingBP vs Age: Pearsons correlation: 0.260
# RestingBP vs Cholesterol: Pearsons correlation: 0.096
# RestingBP vs MaxHR: Pearsons correlation: -0.126

# %%
#linear regression model 

#splitting Data
